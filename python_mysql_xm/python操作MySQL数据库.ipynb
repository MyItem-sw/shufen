# %%
xing = ["赵","钱","孙","李","周","吴","郑","王","冯","陈","褚","卫","蒋","沈","韩","杨","朱","秦","尤","许","何","吕","施","张","孔","曹","严","华","金","魏","陶","姜","戚","谢","邹","喻","柏","水","窦","章","云","苏","潘","葛","奚","范","彭","郎","鲁","韦","昌","马","苗","凤","花","方","俞","任","袁","柳","酆","鲍","史","唐","费","廉","岑","薛","雷","贺","倪","汤","滕","殷","罗","毕","郝","邬","安","常","乐","于","时","傅","皮","卞","齐","康","伍","余","元","卜","顾","孟","平","黄","和","穆","萧","尹","姚","邵","湛","汪","祁","毛","禹","狄","米","贝","明","臧","计","伏","成","戴","谈","宋","茅","庞","熊","纪","舒","屈","项","祝","董","梁","杜","阮","蓝","闵","席","季","麻","强","贾","路","娄","危","江","童","颜","郭","梅","盛","林","刁","钟","徐","邱","骆","高","夏","蔡","田","樊","胡","凌","霍","虞","万","支","柯","昝","管","卢","莫","经","房","裘","缪","干","解","应","宗","丁","宣","贲","邓","郁","单","杭","洪","包","诸","左","石","崔","吉","钮","龚","程","嵇","邢","滑","裴","陆","荣","翁","荀","羊","於","惠","甄","曲","家","封","芮","羿","储","靳","汲","邴","糜","松","井","段","富","巫","乌","焦","巴","弓","牧","隗","山","谷","车","侯","宓","蓬","全","郗","班","仰","秋","仲","伊","宫","宁","仇","栾","暴","甘","钭","厉","戎","祖","武","符","刘","景","詹","束","龙","叶","幸","司","韶","郜","黎","蓟","薄","印","宿","白","怀","蒲","邰","从","鄂","索","咸","籍","赖","卓","蔺","屠","蒙","池","乔","阴","郁","胥","能","苍","双","闻","莘","党","翟","谭","贡","劳","逄","姬","申","扶","堵","冉","宰","郦","雍","却","璩","桑","桂","濮","牛","寿","通","边","扈","燕","冀","郏","浦","尚","农","温","别","庄","晏","柴","瞿","阎","充","慕","连","茹","习","宦","艾","鱼","容","向","古","易","慎","戈","廖","庾","终","暨","居","衡","步","都","耿","满","弘","匡","国","文","寇","广","禄","阙","东","欧","殳","沃","利","蔚","越","夔","隆","师","巩","厍","聂","晁","勾","敖","融","冷","訾","辛","阚","那","简","饶","空","曾","毋","沙","乜","养","鞠","须","丰","巢","关","蒯","相","查","后","荆","红","游","竺","权","逯","盖","益","桓","公","万","俟","司","上官","欧阳","夏侯","诸葛","闻人","东方","赫连","皇甫","尉迟","公羊","澹台","公冶","宗政","濮阳","淳于","单于","太叔","申屠","公孙","仲孙","轩辕","令狐","钟离","宇文","长孙","慕容","鲜于","闾丘","司徒","司空","丌官","司寇","仉督","子车","颛孙","端木","巫马","公西","漆雕","乐正","壤驷","公良","拓跋","夹谷","宰父","谷梁","晋楚","闫法","汝鄢","涂钦","段干","百里","东郭","南门","呼延","归海","羊舌","微生","岳帅","缑亢","况郈","有琴","梁丘","左丘","东门","西门","商牟","佘佴","伯赏","南宫","墨哈","谯笪","年爱","阳佟","第五","言福"]
ming = ["梦琪","忆柳","之桃","慕青","问兰","尔岚","元香","初夏","沛菡","傲珊","曼文","乐菱","痴珊","恨玉","惜文","香寒","新柔","语蓉","海安","夜蓉","涵柏","水桃","醉蓝","春儿","语琴","从彤","傲晴","语兰","又菱","碧彤","元霜","怜梦","紫寒","妙彤","曼易","南莲","紫翠","雨寒","易烟","如萱","若南","寻真","晓亦","向珊","慕灵","以蕊","寻雁","映易","雪柳","孤岚","笑霜","海云","凝天","沛珊","寒云","冰旋","宛儿","绿真","盼儿","晓霜","碧凡","夏菡","曼香","若烟","半梦","雅绿","冰蓝","灵槐","平安","书翠","翠风","香巧","代云","梦曼","幼翠","友巧","听寒","梦柏","醉易","访旋","亦玉","凌萱","访卉","怀亦","笑蓝","春翠","靖柏","夜蕾","冰夏","梦松","书雪","乐枫","念薇","靖雁","寻春","恨山","从寒","忆香","觅波","静曼","凡旋","以亦","念露","芷蕾","千兰","新波","代真","新蕾","雁玉","冷卉","紫山","千琴","恨天","傲芙","盼山","怀蝶","冰兰","山柏","翠萱","恨松","问旋","从南","白易","问筠","如霜","半芹","丹珍","冰彤","亦寒","寒雁","怜云","寻文","乐丹","翠柔","谷山","之瑶","冰露","尔珍","谷雪","乐萱","涵菡","海莲","傲蕾","青槐","冬儿","易梦","惜雪","宛海","之柔","夏青","亦瑶","妙菡","春竹","痴梦","紫蓝","晓巧","幻柏","元风","冰枫","访蕊","南春","芷蕊","凡蕾","凡柔","安蕾","天荷","含玉","书兰","雅琴","书瑶","春雁","从安","夏槐","念芹","怀萍","代曼","幻珊","谷丝","秋翠","白晴","海露","代荷","含玉","书蕾","听白","访琴","灵雁","秋春","雪青","乐瑶","含烟","涵双","平蝶","雅蕊","傲之","灵薇","绿春","含蕾","从梦","从蓉","初丹","听兰","听蓉","语芙","夏彤","凌瑶","忆翠","幻灵","怜菡","紫南","依珊","妙竹","访烟","怜蕾","映寒","友绿","冰萍","惜霜","凌香","芷蕾","雁卉","迎梦","元柏","代萱","紫真","千青","凌寒","紫安","寒安","怀蕊","秋荷","涵雁","以山","凡梅","盼曼","翠彤","谷冬","新巧","冷安","千萍","冰烟","雅阳","友绿","南松","诗云","飞风","寄灵","书芹","幼蓉","以蓝","笑寒","忆寒","秋烟","芷巧","水香","映之","醉波","幻莲","夜山","芷卉","向彤","小玉","幼南","凡梦","尔曼","念波","迎松","青寒","笑天","涵蕾","碧菡","映秋","盼烟","忆山","以寒","寒香","小凡","代亦","梦露","映波","友蕊","寄凡","怜蕾","雁枫","水绿","曼荷","笑珊","寒珊","谷南","慕儿","夏岚","友儿","小萱","紫青","妙菱","冬寒","曼柔","语蝶","青筠","夜安","觅海","问安","晓槐","雅山","访云","翠容","寒凡","晓绿","以菱","冬云","含玉","访枫"]

# %%
import random
import time
import pymysql

# %%
##  连接数据库
# 声明一个变量
db_info = {
    "host":"localhost", # 要连接的数据库的IP地址或者是域名，如果是本地的话可以写localhost或者是127.0.0.1
    "user":"root", # 连接数据库的用户名
    "password":"root", # 连接数据库的密码
    "database":"management_systems", # 我们要连接的数据库的名字
    "charset":"utf8" # 这是字符集
}

# 开始连接
conn = pymysql.connect(**db_info)

# cursor是执行sql语句的对象
cursor = conn.cursor()

# %%
## 简单的演示
sql = "select * from school"
cursor.execute(sql)
# Out:
# 4

# %%
## 查询时，获取数据
cursor.fetchall()
# Out:
# ((1, '第一实验小学', '南京路1号'),
#  (2, '第十中学', '北京路2号'),
#  (3, '实验中学', ''),
#  (4, '第八中学', None))

# %%
# sql语句格式化的演示
sql = "select %s from student where class_id=%s and sex=%s" % ("student_name","1","1")
cursor.execute(sql)
cursor.fetchall()
# Out:
# (('谯笪代曼',),
#  ('昝凡旋',),
#  ('后沛珊',),
#  ('米笑寒',),
#  ('窦又菱',),
#  ('杭水香',),
#  ('梅芷蕾',),
#  ('郁新柔',),
#  ('单于恨天',),
#  ('龙怀蝶',),
#  ('盛访蕊',),
#  ('闻人春竹',),
#  ('全惜霜',),
#  ('禹书翠',),
#  ('家靖柏',),
#  ('荣秋春',),
#  ('巫马冰夏',),
#  ('沃秋荷',),
#  ('苍傲珊',),
#  ('糜向珊',),
#  ('晏新波',),
#  ('饶凡旋',),
#  ('徐访旋',),
#  ('刁怜蕾',),
#  ('鲁笑寒',),
#  ('酆恨玉',),
#  ('晁幻柏',),
#  ('缪友绿',),
#  ('万盼儿',),
#  ('全夏彤',),
#  ('路语琴',),
#  ('余凌寒',),
#  ('钭痴梦',),
#  ('漆雕秋烟',),
#  ('鲜于谷南',),
#  ('苗秋春',),
#  ('终从梦',),
#  ('束灵薇',),
#  ('申屠雪青',),
#  ('符怜菡',),
#  ('汲涵菡',),
#  ('司慕青',),
#  ('璩痴珊',),
#  ('万小凡',),
#  ('贾问筠',),
#  ('巫马访烟',),
#  ('安从南',),
#  ('夹谷谷山',),
#  ('赵紫蓝',),
#  ('邱水桃',),
#  ('弓冰旋',),
#  ('乔白易',),
#  ('羊从蓉',),
#  ('荀书瑶',),
#  ('仲访烟',),
#  ('蔡寄凡',),
#  ('端木寒安',),
#  ('奚晓槐',),
#  ('颜以蕊',),
#  ('董易梦',),
#  ('呼延夜蓉',),
#  ('仲孙曼柔',),
#  ('严半芹',),
#  ('郑小凡',),
#  ('汪友蕊',),
#  ('车海安',),
#  ('景雅绿',),
#  ('胡惜霜',),
#  ('路翠萱',),
#  ('边翠容',),
#  ('严凡梦',),
#  ('臧丹珍',),
#  ('韦忆翠',),
#  ('殷雨寒',),
#  ('支以蓝',),
#  ('伊冰烟',),
# ...

# %%
# 第二种格式化
params = {
    "class_id":1,
    "student_name":"student_name",
    "student_birthday":"student_birthday",
    "sex":1
}
sql = "select {student_name},{student_birthday} from student where class_id={class_id} and sex={sex}".format(**params)
cursor.execute(sql)
cursor.fetchall()
# Out:
# (('谯笪代曼', datetime.date(1983, 10, 3)),
#  ('昝凡旋', datetime.date(1984, 8, 14)),
#  ('后沛珊', datetime.date(1996, 10, 9)),
#  ('米笑寒', datetime.date(1995, 8, 27)),
#  ('窦又菱', datetime.date(1997, 5, 15)),
#  ('杭水香', datetime.date(1984, 5, 14)),
#  ('梅芷蕾', datetime.date(1980, 11, 25)),
#  ('郁新柔', datetime.date(1984, 11, 21)),
#  ('单于恨天', datetime.date(1993, 3, 23)),
#  ('龙怀蝶', datetime.date(1983, 4, 18)),
#  ('盛访蕊', datetime.date(1995, 2, 10)),
#  ('闻人春竹', datetime.date(1998, 10, 29)),
#  ('全惜霜', datetime.date(1995, 9, 28)),
#  ('禹书翠', datetime.date(1993, 7, 6)),
#  ('家靖柏', datetime.date(1981, 11, 8)),
#  ('荣秋春', datetime.date(1998, 6, 7)),
#  ('巫马冰夏', datetime.date(1999, 11, 19)),
#  ('沃秋荷', datetime.date(1987, 10, 31)),
#  ('苍傲珊', datetime.date(1988, 12, 21)),
#  ('糜向珊', datetime.date(1983, 11, 21)),
#  ('晏新波', datetime.date(1994, 6, 8)),
#  ('饶凡旋', datetime.date(1990, 12, 9)),
#  ('徐访旋', datetime.date(1987, 12, 9)),
#  ('刁怜蕾', datetime.date(1990, 2, 8)),
# ...

# %%
# 第二种饭方式动态选择，根据性别
params = {
    "class_id":1,
    "student_name":"student_name",
    "student_birthday":"student_birthday",
    "sex":1
}

sql = "select {student_name},{student_birthday} from student where class_id={class_id} and sex={sex}".format(**params)
cursor.execute(sql)
cursor.fetchall()
# Out:
# (('谯笪代曼', datetime.date(1983, 10, 3)),
#  ('昝凡旋', datetime.date(1984, 8, 14)),
#  ('后沛珊', datetime.date(1996, 10, 9)),
#  ('米笑寒', datetime.date(1995, 8, 27)),
#  ('窦又菱', datetime.date(1997, 5, 15)),
#  ('杭水香', datetime.date(1984, 5, 14)),
#  ('梅芷蕾', datetime.date(1980, 11, 25)),
#  ('郁新柔', datetime.date(1984, 11, 21)),
#  ('单于恨天', datetime.date(1993, 3, 23)),
#  ('龙怀蝶', datetime.date(1983, 4, 18)),
#  ('盛访蕊', datetime.date(1995, 2, 10)),
#  ('闻人春竹', datetime.date(1998, 10, 29)),
#  ('全惜霜', datetime.date(1995, 9, 28)),
#  ('禹书翠', datetime.date(1993, 7, 6)),
#  ('家靖柏', datetime.date(1981, 11, 8)),
#  ('荣秋春', datetime.date(1998, 6, 7)),
#  ('巫马冰夏', datetime.date(1999, 11, 19)),
#  ('沃秋荷', datetime.date(1987, 10, 31)),
#  ('苍傲珊', datetime.date(1988, 12, 21)),
#  ('糜向珊', datetime.date(1983, 11, 21)),
#  ('晏新波', datetime.date(1994, 6, 8)),
#  ('饶凡旋', datetime.date(1990, 12, 9)),
#  ('徐访旋', datetime.date(1987, 12, 9)),
#  ('刁怜蕾', datetime.date(1990, 2, 8)),
# ...

# %%
## 插入数据，学生表
# insert into student(class_id,student_name,student_birthday,sex) values(......)
# 我们先来生成是国内日字段
a1 = (1980,1,1,0,0,0,0,0,0) # 这个代表生日的开始时间
a2 = (2000,12,31,23,59,59,0,0,0) # 这个代表生日的结束时间

# 进行时间上的转换
start = time.mktime(a1)
end = time.mktime(a2)

# %%
start
# Out:
# 315504000.0

# %%
end
# Out:
# 978278399.0

# %%
# 有36个班级
import random
for i in range(1,37):
    # 假设每个班级有50名学生
    for j in range(1,51):
        random_xing = random.randint(0,len(xing)-1)
        random_ming = random.randint(0,len(ming)-1)
        
        t = random.randint(start,end)# 在时间戳中随机选择一个
        data_t = time.localtime(t)# 把时间戳转换为成时间
        birthday = time.strftime("%Y-%m-%d", data_t) # 把时间转换成一个可以插入数据库的时间格式
        
        
        # 拼接sql
        sql = "insert into student(class_id,student_name,student_birthday,sex) values( " + str(i) +",'" + xing[random_xing] + ming[random_ming] + "','" + birthday +"',"+str(random.randint(0,1))+")"            
        print(sql)
        cursor.execute(sql)
# Out:
# insert into student(class_id,student_name,student_birthday,sex) values( 1,'柳春雁','2000-05-10',0)
# insert into student(class_id,student_name,student_birthday,sex) values( 1,'贝以山','1990-12-05',0)
# insert into student(class_id,student_name,student_birthday,sex) values( 1,'西门夏岚','1982-03-06',1)
# insert into student(class_id,student_name,student_birthday,sex) values( 1,'宗政念薇','1990-08-03',1)
# insert into student(class_id,student_name,student_birthday,sex) values( 1,'戴幻柏','1998-07-15',1)
# insert into student(class_id,student_name,student_birthday,sex) values( 1,'游之桃','1991-04-13',1)
# insert into student(class_id,student_name,student_birthday,sex) values( 1,'屠紫蓝','2000-06-08',1)
# insert into student(class_id,student_name,student_birthday,sex) values( 1,'翟碧凡','1998-01-17',1)
# insert into student(class_id,student_name,student_birthday,sex) values( 1,'杜忆翠','1986-11-29',0)
# insert into student(class_id,student_name,student_birthday,sex) values( 1,'危幼南','1999-05-09',0)
# ...

# %%
## 插入数据的时候，必须要有一个提交的动作，否则写不进去
conn.commit()

# %%
## 要插入学生的分数就需要查询出学生的id和课程的id，并且最终插入的分数不能超过满分，所以我们还得查询出这个课程的满分是多少
get_student_info_sql="""
SELECT s.id,cc.id,cc.full_mark
FROM grade g
JOIN class c 
ON g.id = c.grade_id
JOIN student s
ON c.id = s.class_id
JOIN course cc
ON g.id = cc.grade_id
"""
cursor.execute(get_student_info_sql)
result = cursor.fetchall()
result
# Out:
# ((1, 1, 100),
#  (1, 2, 100),
#  (1, 3, 100),
#  (2, 1, 100),
#  (2, 2, 100),
#  (2, 3, 100),
#  (3, 1, 100),
#  (3, 2, 100),
#  (3, 3, 100),
#  (4, 1, 100),
#  (4, 2, 100),
#  (4, 3, 100),
#  (5, 1, 100),
#  (5, 2, 100),
#  (5, 3, 100),
#  (6, 1, 100),
#  (6, 2, 100),
#  (6, 3, 100),
#  (7, 1, 100),
#  (7, 2, 100),
#  (7, 3, 100),
#  (8, 1, 100),
#  (8, 2, 100),
#  (8, 3, 100),
#  (9, 1, 100),
#  (9, 2, 100),
#  (9, 3, 100),
#  (10, 1, 100),
#  (10, 2, 100),
#  (10, 3, 100),
#  (11, 1, 100),
#  (11, 2, 100),
#  (11, 3, 100),
#  (12, 1, 100),
#  (12, 2, 100),
#  (12, 3, 100),
#  (13, 1, 100),
#  (13, 2, 100),
#  (13, 3, 100),
#  (14, 1, 100),
#  (14, 2, 100),
#  (14, 3, 100),
#  (15, 1, 100),
#  (15, 2, 100),
#  (15, 3, 100),
#  (16, 1, 100),
#  (16, 2, 100),
#  (16, 3, 100),
#  (17, 1, 100),
#  (17, 2, 100),
#  (17, 3, 100),
#  (18, 1, 100),
#  (18, 2, 100),
#  (18, 3, 100),
#  (19, 1, 100),
#  (19, 2, 100),
#  (19, 3, 100),
#  (20, 1, 100),
#  (20, 2, 100),
#  (20, 3, 100),
# ...

# %%
# 插入分数

for i in range(len(result)):
    insert_values = result[i]
    score = random.randint(0,insert_values[2])
    sql="""
    insert into score(student_id,course_id,score) values (%s,%s,%s)
    
    
    """%(insert_values[0],insert_values[1],score)
    cursor.execute(sql)
conn.commit()

# %% [markdown]
# # 关闭连接

# %%
cursor.close()
conn.close()

# %%
import pymysql
import pandas as pd

# %%
db_info = {
    "host":"localhost",
    "user":"root",
    "password":"root",
    "database":"management_systems",
    "charset":"utf8"
}

conn = pymysql.connect(**db_info)
cursor = conn.cursor()

# %% [markdown]
# # 关联查询和DataFrame数据类型中的数据关联对比

# %%
import pandas as pd
get_school_data_sql = 'select * from school'
get_grade_sql = 'select * from grade'
school_data = pd.read_sql(get_school_data_sql,conn)
grade_data = pd.read_sql(get_grade_sql,conn)

# %%
school_data
# Out:
#    id school_name school_address
# 0   1      第一实验小学          南京路1号
# 1   2        第十中学          北京路2号
# 2   3        实验中学
# 3   4        第八中学           None

# %%
grade_data
# Out:
#     id  school_id grade_name
# 0    1          1        一年级
# 1    2          1        二年级
# 2    3          1        三年级
# 3    4          1        四年级
# 4    5          1        五年级
# 5    6          1        六年级
# 6    7          2        一年级
# 7    8          2        二年级
# 8    9          2        三年级
# 9   10          3        一年级
# 10  11          3        二年级
# 11  12          3        三年级
# 12  13          5

# %% [markdown]
# # 用pandas中的merge来进行数据的关联

# %%
data = pd.merge(
    school_data,# 左表
    grade_data,# 右表
    left_on = ['id'],# 左表取出哪个字段和右表关联
    right_on = ['school_id'],# 右表取出哪个字段和左表关联
    how = 'left'
)
data
# Out:
#     id_x school_name school_address  id_y  school_id grade_name
# 0      1      第一实验小学          南京路1号   1.0        1.0        一年级
# 1      1      第一实验小学          南京路1号   2.0        1.0        二年级
# 2      1      第一实验小学          南京路1号   3.0        1.0        三年级
# 3      1      第一实验小学          南京路1号   4.0        1.0        四年级
# 4      1      第一实验小学          南京路1号   5.0        1.0        五年级
# 5      1      第一实验小学          南京路1号   6.0        1.0        六年级
# 6      2        第十中学          北京路2号   7.0        2.0        一年级
# 7      2        第十中学          北京路2号   8.0        2.0        二年级
# 8      2        第十中学          北京路2号   9.0        2.0        三年级
# 9      3        实验中学                 10.0        3.0        一年级
# 10     3        实验中学                 11.0        3.0        二年级
# 11     3        实验中学                 12.0        3.0        三年级
# 12     4        第八中学           None   NaN        NaN        NaN

# %%
left_join_sql = """
SELECT s.id sid, s.school_name,s.school_address, g.* 
FROM school s
LEFT JOIN grade g
on s.id = g.school_id
"""

result = pd.read_sql(left_join_sql,conn)
result
# Out:
#     sid school_name school_address    id  school_id grade_name
# 0     1      第一实验小学          南京路1号   1.0        1.0        一年级
# 1     1      第一实验小学          南京路1号   2.0        1.0        二年级
# 2     1      第一实验小学          南京路1号   3.0        1.0        三年级
# 3     1      第一实验小学          南京路1号   4.0        1.0        四年级
# 4     1      第一实验小学          南京路1号   5.0        1.0        五年级
# 5     1      第一实验小学          南京路1号   6.0        1.0        六年级
# 6     2        第十中学          北京路2号   7.0        2.0        一年级
# 7     2        第十中学          北京路2号   8.0        2.0        二年级
# 8     2        第十中学          北京路2号   9.0        2.0        三年级
# 9     3        实验中学                 10.0        3.0        一年级
# 10    3        实验中学                 11.0        3.0        二年级
# 11    3        实验中学                 12.0        3.0        三年级
# 12    4        第八中学           None   NaN        NaN       None

# %% [markdown]
# # 多表之间的关联

# %%
## 多表之间的关联
left_join_sql = """
SELECT s.*, g.*,c.* 
FROM school s
LEFT JOIN grade g
ON s.id = g.school_id
LEFT JOIN class c
ON g.id = c.grade_id

"""
result = pd.read_sql(left_join_sql,conn)
result
# Out:
#     id school_name school_address    id  school_id grade_name    id  grade_id  \
# 0    1      第一实验小学          南京路1号   1.0        1.0        一年级   1.0       1.0
# 1    1      第一实验小学          南京路1号   1.0        1.0        一年级   2.0       1.0
# 2    1      第一实验小学          南京路1号   1.0        1.0        一年级   3.0       1.0
# 3    1      第一实验小学          南京路1号   2.0        1.0        二年级   4.0       2.0
# 4    1      第一实验小学          南京路1号   2.0        1.0        二年级   5.0       2.0
# 5    1      第一实验小学          南京路1号   2.0        1.0        二年级   6.0       2.0
# 6    1      第一实验小学          南京路1号   3.0        1.0        三年级   7.0       3.0
# 7    1      第一实验小学          南京路1号   3.0        1.0        三年级   8.0       3.0
# 8    1      第一实验小学          南京路1号   3.0        1.0        三年级   9.0       3.0
# 9    1      第一实验小学          南京路1号   4.0        1.0        四年级  10.0       4.0
# 10   1      第一实验小学          南京路1号   4.0        1.0        四年级  11.0       4.0
# ...

# %%
df = pd.merge(
    school_data, # 左表
    grade_data,  # 右表
    left_on = ['id'], # 左边的表取出哪个字段和右边的表进行关联
    right_on = ['school_id'], # 右边的表取出哪个字段和左边的表关联
    how = 'left'  # 这个就是用什么关联方式
)
df
# Out:
#     id_x school_name school_address  id_y  school_id grade_name
# 0      1      第一实验小学          南京路1号   1.0        1.0        一年级
# 1      1      第一实验小学          南京路1号   2.0        1.0        二年级
# 2      1      第一实验小学          南京路1号   3.0        1.0        三年级
# 3      1      第一实验小学          南京路1号   4.0        1.0        四年级
# 4      1      第一实验小学          南京路1号   5.0        1.0        五年级
# 5      1      第一实验小学          南京路1号   6.0        1.0        六年级
# 6      2        第十中学          北京路2号   7.0        2.0        一年级
# 7      2        第十中学          北京路2号   8.0        2.0        二年级
# 8      2        第十中学          北京路2号   9.0        2.0        三年级
# 9      3        实验中学                 10.0        3.0        一年级
# 10     3        实验中学                 11.0        3.0        二年级
# 11     3        实验中学                 12.0        3.0        三年级
# 12     4        第八中学           None   NaN        NaN        NaN

# %%
class_data = pd.read_sql('select * from class',conn)
df2 = pd.merge(
    df, # 左表
    class_data,  # 右表
    left_on = ['id_y'], # 左边的表取出哪个字段和右边的表进行关联
    right_on = ['grade_id'], # 右边的表取出哪个字段和左边的表关联
    how = 'left'  # 这个就是用什么关联方式
)
df2
# Out:
#     id_x school_name school_address id_y  school_id grade_name    id  \
# 0      1      第一实验小学          南京路1号    1        1.0        一年级   1.0
# 1      1      第一实验小学          南京路1号    1        1.0        一年级   2.0
# 2      1      第一实验小学          南京路1号    1        1.0        一年级   3.0
# 3      1      第一实验小学          南京路1号    2        1.0        二年级   4.0
# 4      1      第一实验小学          南京路1号    2        1.0        二年级   5.0
# 5      1      第一实验小学          南京路1号    2        1.0        二年级   6.0
# 6      1      第一实验小学          南京路1号    3        1.0        三年级   7.0
# 7      1      第一实验小学          南京路1号    3        1.0        三年级   8.0
# 8      1      第一实验小学          南京路1号    3        1.0        三年级   9.0
# 9      1      第一实验小学          南京路1号    4        1.0        四年级  10.0
# 10     1      第一实验小学          南京路1号    4        1.0        四年级  11.0
# 11     1      第一实验小学          南京路1号    4        1.0        四年级  12.0
# 12     1      第一实验小学          南京路1号    5        1.0        五年级  13.0
# ...

# %% [markdown]
# # 右关联和全关联

# %%
df = pd.merge(
    school_data, # 左表
    grade_data,  # 右表
    left_on = ['id'], # 左边的表取出哪个字段和右边的表进行关联
    right_on = ['school_id'], # 右边的表取出哪个字段和左边的表关联
    how = 'right'  # 这个就是用什么关联方式
)
df
# Out:
#     id_x school_name school_address  id_y  school_id grade_name
# 0    1.0      第一实验小学          南京路1号     1          1        一年级
# 1    1.0      第一实验小学          南京路1号     2          1        二年级
# 2    1.0      第一实验小学          南京路1号     3          1        三年级
# 3    1.0      第一实验小学          南京路1号     4          1        四年级
# 4    1.0      第一实验小学          南京路1号     5          1        五年级
# 5    1.0      第一实验小学          南京路1号     6          1        六年级
# 6    2.0        第十中学          北京路2号     7          2        一年级
# 7    2.0        第十中学          北京路2号     8          2        二年级
# 8    2.0        第十中学          北京路2号     9          2        三年级
# 9    3.0        实验中学                   10          3        一年级
# 10   3.0        实验中学                   11          3        二年级
# 11   3.0        实验中学                   12          3        三年级
# 12   NaN         NaN            NaN    13          5

# %%
df = pd.merge(
    school_data, # 左表
    grade_data,  # 右表
    left_on = ['id'], # 左边的表取出哪个字段和右边的表进行关联
    right_on = ['school_id'], # 右边的表取出哪个字段和左边的表关联
    how = 'inner'  # 这个就是用什么关联方式
)
df
# Out:
#     id_x school_name school_address  id_y  school_id grade_name
# 0      1      第一实验小学          南京路1号     1          1        一年级
# 1      1      第一实验小学          南京路1号     2          1        二年级
# 2      1      第一实验小学          南京路1号     3          1        三年级
# 3      1      第一实验小学          南京路1号     4          1        四年级
# 4      1      第一实验小学          南京路1号     5          1        五年级
# 5      1      第一实验小学          南京路1号     6          1        六年级
# 6      2        第十中学          北京路2号     7          2        一年级
# 7      2        第十中学          北京路2号     8          2        二年级
# 8      2        第十中学          北京路2号     9          2        三年级
# 9      3        实验中学                   10          3        一年级
# 10     3        实验中学                   11          3        二年级
# 11     3        实验中学                   12          3        三年级
